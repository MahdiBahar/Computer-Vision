# %% [markdown]
# # Practice 13

# %% [markdown]
# # Pandas

# %% [markdown]
# ### Exercise 1

# %%
import pandas as pd
df = pd.read_csv('cancer.csv')

# %% [markdown]
# ### Excercise 2

# %%
pd.set_option('display.max_rows', None)
df
# Out:
#                    State  Total.Rate  Total.Number  Total.Population  \
# 0                Alabama       214.2       71529.0        33387205.0
# 1                 Alaska       128.1        6361.0         4966180.0
# 2                Arizona       165.6       74286.0        44845598.0
# 3               Arkansas       223.9       45627.0        20382448.0
# 4             California       150.9      393980.0       261135696.0
# 5               Colorado       139.0       49035.0        35267734.0
# 6            Connecticut       190.5       47567.0        24975889.0
# 7               Delaware       210.2       13233.0         6295263.0
# 8   District of Columbia       182.1        7730.0         4245359.0
# 9                Florida       219.2      289905.0       132277071.0
# 10               Georgia       159.4      108222.0        67890652.0
# 11                Hawaii       166.0       15812.0         9526083.0
# 12                 Idaho       162.1       17756.0        10954295.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   State                                         51 non-null     object
#  1   Total.Rate                                    51 non-null     float64
#  2   Total.Number                                  51 non-null     float64
#  3   Total.Population                              51 non-null     float64
#  4   Rates.Age.< 18                                51 non-null     float64
#  5   Rates.Age.18-45                               51 non-null     float64
#  6   Rates.Age.45-64                               51 non-null     float64
#  7   Rates.Age.> 64                                51 non-null     float64
#  8   Rates.Age and Sex.< 18.Female                 51 non-null     float64
# ...

# %%
df.describe()
# Out:
#        Total.Rate   Total.Number  Total.Population  Rates.Age.< 18  \
# count   51.000000      51.000000      5.100000e+01       51.000000
# mean   190.656863   78723.725490      4.240151e+07        2.119608
# std     28.592155   80861.292676      4.784244e+07        0.502004
# min     98.500000    6361.000000      3.931624e+06        0.000000
# 25%    176.500000   20631.000000      1.186991e+07        2.050000
# 50%    196.100000   54930.000000      3.034806e+07        2.200000
# 75%    210.750000   93328.000000      4.650326e+07        2.400000
# max    254.600000  393980.000000      2.611357e+08        2.700000
#
#        Rates.Age.18-45  Rates.Age.45-64  Rates.Age.> 64  \
# count        51.000000        51.000000       51.000000
# mean         14.764706       197.576471      980.949020
# std           2.204343        31.261040       75.189556
# min          10.000000       132.300000      735.800000
# 25%          13.350000       175.000000      943.550000
# ...

# %% [markdown]
# ### Exercise3

# %%
df.tail(13)
# Out:
#              State  Total.Rate  Total.Number  Total.Population  \
# 38    Pennsylvania       227.7      202230.0        88825682.0
# 39    Rhode Island       211.2       15570.0         7371636.0
# 40  South Carolina       202.6       65561.0        32366134.0
# 41    South Dakota       196.2       11212.0         5714307.0
# 42       Tennessee       213.1       94678.0        44430836.0
# 43           Texas       145.8      257000.0       176270421.0
# 44            Utah        98.5       19022.0        19321462.0
# 45         Vermont       211.6        9261.0         4377262.0
# 46        Virginia       177.1       99278.0        56054333.0
# 47      Washington       175.9       82864.0        47114240.0
# 48   West Virginia       254.6       32950.0        12940212.0
# 49       Wisconsin       197.5       78578.0        39788899.0
# 50         Wyoming       167.9        6603.0         3931624.0
#
#     Rates.Age.< 18  Rates.Age.18-45  Rates.Age.45-64  Rates.Age.> 64  \
# ...

# %% [markdown]
# ### Exercise 4

# %%
df[df['Total.Rate']<200].State
# Out:
# 1                   Alaska
# 2                  Arizona
# 4               California
# 5                 Colorado
# 6              Connecticut
# 8     District of Columbia
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 16                  Kansas
# 20                Maryland
# 21           Massachusetts
# 23               Minnesota
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# 34            North Dakota
# 37                  Oregon
# 41            South Dakota
# 43                   Texas
# 44                    Utah
# 46                Virginia
# 47              Washington
# 49               Wisconsin
# 50                 Wyoming
# Name: State, dtype: object

# %% [markdown]
# ### Exercise 5

# %%
print(f'''The number os states with total rate < 200 is :
      {df[df['Total.Rate']<200].State.value_counts().sum()}''')
# Out:
# The number os states with total rate < 200 is :
#       31

# %% [markdown]
# ### Exercise 6

# %%
df.iloc[35:, 14:28]
# Out:
#     Rates.Age and Sex.> 64.Female  Rates.Age and Sex.> 64.Male  \
# 35                          895.1                       1288.3
# 36                          855.6                       1279.4
# 37                          866.0                       1169.2
# 38                          898.6                       1276.5
# 39                          884.4                       1291.3
# 40                          775.1                       1195.1
# 41                          860.7                       1195.0
# 42                          834.4                       1294.7
# 43                          750.2                       1104.0
# 44                          611.6                        884.9
# 45                          872.8                       1165.8
# 46                          819.2                       1170.7
# 47                          852.4                       1142.0
# 48                          889.6                       1299.9
# ...

# %% [markdown]
# ### Exercise 7

# %%
df['Rates.Age.< 18'].unique()
# Out:
# array([2. , 1.7, 2.5, 2.3, 2.6, 1.9, 1.6, 2.2, 0. , 2.1, 2.4, 2.7, 1.4])

# %% [markdown]
# ### Exercise 8

# %%
round(df['Rates.Age.< 18'].mean(),4)
# Out:
# 2.1196

# %% [markdown]
# ### Exercise 9

# %%
df['Total.Population'].max()
# Out:
# 261135696.0

# %%
df['Total.Population'].apply(lambda x: df['Total.Population'].max()-x)
# Out:
# 0     227748491.0
# 1     256169516.0
# 2     216290098.0
# 3     240753248.0
# 4             0.0
# 5     225867962.0
# 6     236159807.0
# 7     254840433.0
# 8     256890337.0
# 9     128858625.0
# 10    193245044.0
# 11    251609613.0
# 12    250181401.0
# 13    171438735.0
# 14    215763006.0
# 15    239813614.0
# 16    241206913.0
# 17    230787639.0
# 18    229497310.0
# 19    251834514.0
# 20    220651717.0
# 21    215243424.0
# 22    191747123.0
# 23    223951967.0
# 24    240378824.0
# 25    219297306.0
# 26    254202673.0
# 27    248350172.0
# 28    242223389.0
# 29    251912307.0
# 30    199614141.0
# 31    246785934.0
# 32    125419172.0
# 33    194466627.0
# 34    256380793.0
# 35    180394453.0
# 36    234906552.0
# 37    234303580.0
# 38    172310014.0
# 39    253764060.0
# 40    228769562.0
# 41    255421389.0
# 42    216704860.0
# 43     84865275.0
# 44    241814234.0
# 45    256758434.0
# 46    205081363.0
# 47    214021456.0
# 48    248195484.0
# 49    221346797.0
# ...

# %% [markdown]
# ### if we want to add this data to the dataframe, we should do this:

# %%
df['Subtract_Total.Population'] = df['Total.Population'].apply(lambda x:df['Total.Population'].max()-x)

# %%
df
# Out:
#                    State  Total.Rate  Total.Number  Total.Population  \
# 0                Alabama       214.2       71529.0        33387205.0
# 1                 Alaska       128.1        6361.0         4966180.0
# 2                Arizona       165.6       74286.0        44845598.0
# 3               Arkansas       223.9       45627.0        20382448.0
# 4             California       150.9      393980.0       261135696.0
# 5               Colorado       139.0       49035.0        35267734.0
# 6            Connecticut       190.5       47567.0        24975889.0
# 7               Delaware       210.2       13233.0         6295263.0
# 8   District of Columbia       182.1        7730.0         4245359.0
# 9                Florida       219.2      289905.0       132277071.0
# 10               Georgia       159.4      108222.0        67890652.0
# 11                Hawaii       166.0       15812.0         9526083.0
# 12                 Idaho       162.1       17756.0        10954295.0
# ...

# %% [markdown]
# ### So, at the end of the dataframe, new data is added
